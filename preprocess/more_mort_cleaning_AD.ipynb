# %% [markdown]
# ## Cleaning File for Data mort_2016, mort_2017 AND mort_2011, mort_2012

# %%
import pandas as pd
import csv
pd.set_option('display.max_columns', 100)

# %%
# %time mort_2018 = pd.read_csv('data/mort_2018_filtered.csv', low_memory=False)
# Out:
# Wall time: 2min 42s

# %%
mort_2018.shape
mort_2018.sample(7)
# Out:
#          resident_status  edu edu_1989_rev  edu_2003_rev  edu_reporting_flag  \
# 1679649                3   31                          3                   1
# 1378541                1   31                          3                   1
# 349362                 1   61                          6                   1
# 1213571                2   21                          2                   1
# 2008283                1   31                          3                   1
# 2490012                1   31                          3                   1
# 1230601                1   31                          3                   1
#
#          month_of_death sex  reported_age_tmstmp_flag  reported_age  \
# 1679649               5   F                         1  078 412110
# 1378541               3   F                         1  087 432311
# 349362               10   M                         1  057 371708
# 1213571               2   F                         1  085 432311
# ...

# %%
mort_2018.columns
# Out:
# Index(['resident_status', 'edu', 'edu_1989_rev', 'edu_2003_rev',
#        'edu_reporting_flag', 'month_of_death', 'sex',
#        'reported_age_tmstmp_flag', 'reported_age', 'age_detail',
#        'age_sub_flag', 'age_recode_52', 'age_recode_27', 'age_recode_12',
#        'infant_age_recode_22', 'place_of_death_and_status', 'marital_status',
#        'day_of_week_of_death', 'data_year', 'injury_at_work',
#        'manner_of_death', 'method_of_disposition', 'autopsy', 'activity_code',
#        'place_of_injury', 'activity_code_1', 'underlying_cause_of_death',
#        'icd_10th_revision', 'cause_recode_358', 'cause_recode_113',
#        'infant_cause_130', 'cause_recode_39', 'multiple_conditions',
#        'number_of_entityaxis_conditions', 'entityaxis_conditions_con',
#        'entAx_condition_1st', 'entAx_condition_2nd', 'entAx_condition_3rd',
#        'entAx_condition_4th', 'entAx_condition_5th', 'entAx_condition_6th',
# ...

# %%
mort_2018['cause_recode_358'].dtype
# Out:
# dtype('int64')

# %%
m2018_flu = mort_2018[mort_2018['cause_recode_358']==253]

# %%
m2018_flu.shape
# Out:
# (11164, 85)

# %%
m2018_flu.sample(10)
# Out:
#          resident_status  edu edu_1989_rev  edu_2003_rev  edu_reporting_flag  \
# 2223792                2   21                          2                   1
# 2000305                1   31                          3                   1
# 2135194                1   61                          6                   1
# 1030490                1   31                          3                   1
# 877900                 1   31                          3                   1
# 150989                 1   31                          3                   1
# 1156246                1   61                          6                   1
# 1101749                1   21                          2                   1
# 164185                 1   31                          3                   1
# 2081948                2   31                          3                   1
#
#          month_of_death sex  reported_age_tmstmp_flag  reported_age  \
# ...
